# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

df = pd.read_csv("data/processed/student_scores_processed.csv")
df.head()
# Out:
#    student_id  attendance  assignments_completed  midterm_score  final_score  \
# 0           1          74                     10             58           60
# 1           2          70                      6             57           47
# 2           3         100                      7             85           93
# 3           4          84                     10             61           64
# 4           5          73                      5             74           82
#
#                                    feedback
# 0               Very consistent performance
# 1               Needs more practice in math
# 2                      Excellent engagement
# 3               Needs more practice in math
# 4  Strong in theory but weak in application

# %%
print(df.describe())
print(df.info())
# Out:
#        student_id  attendance  assignments_completed  midterm_score  \
# count  100.000000  100.000000             100.000000     100.000000
# mean    50.500000   84.750000               7.440000      73.420000
# std     29.011492    9.524424               1.782746      13.151165
# min      1.000000   70.000000               5.000000      50.000000
# 25%     25.750000   75.000000               6.000000      61.000000
# 50%     50.500000   84.000000               7.000000      74.500000
# 75%     75.250000   94.000000               9.000000      84.250000
# max    100.000000  100.000000              10.000000      95.000000
#
#        final_score
# count   100.000000
# mean     73.010000
# std      14.983152
# min      43.000000
# 25%      61.500000
# 50%      73.000000
# 75%      87.000000
# max     104.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %%
df.hist(bins=20, figsize=(12,8))
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')  # selects only numeric columns
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
# Get absolute path of your project folder
project_dir = r"C:\Users\Ganika Sharma\Student-Progress-Tracker"

# Build path for the figures folder
figures_dir = os.path.join(project_dir, "reports", "figures")

# Create the folder if it doesn't exist
os.makedirs(figures_dir, exist_ok=True)

# Full path for saving the figure
figure_path = os.path.join(figures_dir, "correlation_heatmap.png")

# Save the figure
plt.savefig(figure_path)
